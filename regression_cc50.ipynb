# %%
# Библиотеки для регрессионного анализа CC50
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import (mean_squared_error, mean_absolute_error, r2_score,
                             explained_variance_score)
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.metrics import (mean_squared_error, mean_absolute_error, r2_score)
from sklearn.model_selection import train_test_split, GridSearchCV
import warnings
warnings.filterwarnings('ignore')

# Оптимизированные настройки визуализации для CC50 регрессии
plt.style.use('seaborn-v0_8-pastel')
sns.set_palette("muted")
plt.rcParams['figure.figsize'] = (13, 7)
plt.rcParams['font.size'] = 11
source_cc50_variable = "CC50, mM"

# %%
df = pd.read_parquet("data/processed_data_full.parquet")

# %%
# Строим график для выбросов
plt.figure(figsize=(12, 4))

sns.boxplot(x=df[source_cc50_variable])

plt.title(f'Boxplot для {source_cc50_variable}')
plt.tight_layout()
plt.show()

# %%
mean = df[source_cc50_variable].mean()
std = df[source_cc50_variable].std()
lower_bound = mean - 3 * std
upper_bound = mean + 3 * std

outliers = df[(df[source_cc50_variable] < lower_bound) | (df[source_cc50_variable] > upper_bound)]

print("Выбросы по правилу:")
outliers
# Out:
# Выбросы по правилу:
#      MaxAbsEStateIndex  MinAbsEStateIndex  MinEStateIndex       qed       SPS  \
# 29            0.167835          -0.492682       -0.336254 -0.374021 -1.320181
# 30            0.189542          -0.534596        0.041379 -0.600427 -1.479133
# 49           -0.635122           0.032249        0.729359  0.664412  1.022232
# 80           -0.621559           0.484260        0.778045  0.676892  1.203891
# 82            0.279511          -1.022494        0.606901 -0.271209  1.382454
# 83            0.279511          -1.022494        0.606901 -0.271209  1.382454
# 84            0.207366          -0.912915        0.627556 -0.271209  1.382454
# 94            0.207366          -0.912915        0.627556 -0.271209  1.382454
# 95            0.279511          -1.022494        0.606901 -0.271209  1.382454
# 110          -1.850559           1.442062        0.881210  0.261183  1.022232
# 182          -2.018123           4.695857        1.231675  0.017003 -1.503969
# 183          -0.016957           1.895032        0.929999 -0.555554  1.138607
# 184           0.207542           1.929275        0.933688 -0.293112  1.924336
# 253          -0.042988          -0.617104        0.057735  0.921485  0.931970
# 297          -0.890024           3.415433        1.093761 -1.144065 -1.503969
# 788          -0.031877           0.236353       -0.197404 -0.636303  0.274890
#
#         MolWt  MaxPartialCharge  MinPartialCharge  FpDensityMorgan1  \
# 29  -0.844268          1.703838          0.676161          1.738376
# 30  -0.859744          1.703837          0.676161          1.996858
# 49  -1.227931         -1.369949          0.189156          1.184487
# 80  -1.212109         -1.425447          0.181197          0.889080
# 82  -1.565942         -0.732016          1.457456          0.915935
# 83  -1.565942         -0.732016          1.457456          0.915935
# 84  -1.565942         -0.771254          1.449725          0.915935
# 94  -1.565942         -0.771254          1.449725          0.915935
# 95  -1.565942         -0.732016          1.457456          0.915935
# 110 -1.243408         -1.558355          1.522779          0.889080
# 182 -1.723462         -1.049372          0.879487          0.652754
# 183 -1.896200         -0.797376          1.445397          0.962932
# 184 -1.581764         -0.775308          1.449412         -1.339904
# 253 -0.576207         -0.822393         -0.724812          0.652754
# 297 -1.888791         -1.084354         -0.834681          2.513821
# 788 -0.844150          0.393757          0.200854          1.601533
#
#      BCUT2D_MWHI  ...  fr_sulfone  fr_term_acetylene  fr_tetrazole  \
# 29      0.600354  ...   -0.096976          -0.032191     -0.032191
# 30      0.598273  ...   -0.096976          -0.032191     -0.032191
# 49     -0.484354  ...   -0.096976          -0.032191     -0.032191
# 80     -0.484343  ...   -0.096976          -0.032191     -0.032191
# 82     -0.491791  ...   -0.096976          -0.032191     -0.032191
# 83     -0.491791  ...   -0.096976          -0.032191     -0.032191
# 84     -0.491883  ...   -0.096976          -0.032191     -0.032191
# 94     -0.491883  ...   -0.096976          -0.032191     -0.032191
# 95     -0.491791  ...   -0.096976          -0.032191     -0.032191
# 110    -0.582397  ...   -0.096976          -0.032191     -0.032191
# 182    -0.576074  ...   -0.096976          -0.032191     -0.032191
# 183    -0.491957  ...   -0.096976          -0.032191     -0.032191
# 184    -0.491925  ...   -0.096976          -0.032191     -0.032191
# 253    -0.465606  ...   -0.096976          -0.032191     -0.032191
# 297    -0.471962  ...   -0.096976          -0.032191     -0.032191
# 788    -0.463048  ...   -0.096976          -0.032191     -0.032191
#
#      fr_thiazole  fr_thiophene  fr_unbrch_alkane   fr_urea     IC50, mM  \
# 29     -0.238522      -0.27518         -0.169643 -0.085436  4095.188563
# 30     -0.238522      -0.27518         -0.169643 -0.085436  4128.529377
# 49     -0.238522      -0.27518         -0.169643 -0.085436    13.824389
# 80     -0.238522      -0.27518         -0.169643 -0.085436    83.619244
# 82     -0.238522      -0.27518         -0.169643 -0.085436    32.843311
# 83     -0.238522      -0.27518         -0.169643 -0.085436  2200.501846
# 84     -0.238522      -0.27518         -0.169643 -0.085436   679.856540
# 94     -0.238522      -0.27518         -0.169643 -0.085436  1646.106754
# 95     -0.238522      -0.27518         -0.169643 -0.085436  3284.331113
# 110    -0.238522      -0.27518         -0.169643 -0.085436    19.655003
# 182    -0.238522      -0.27518         -0.169643 -0.085436   529.636972
# 183    -0.238522      -0.27518         -0.169643 -0.085436   234.211171
# 184    -0.238522      -0.27518         -0.169643 -0.085436  1131.658479
# 253    -0.238522      -0.27518         -0.169643 -0.085436   502.962087
# 297    -0.238522      -0.27518         -0.169643 -0.085436  1170.106480
# 788    -0.238522      -0.27518         -0.169643 -0.085436    15.359794
#
#         CC50, mM          SI
# 29   4095.188563    1.000000
# 30   4128.529377    1.000000
# 49   2560.072092  185.185185
# 80   2533.916472   30.303030
# 82   3284.331113  100.000000
# 83   3284.331113    1.492537
# 84   3284.331113    4.830918
# 94   3284.331113    1.995211
# 95   3284.331113    1.000000
# 110  2586.184602  131.578947
# 182  3934.446075    7.428571
# 183  4538.976189   19.379845
# 184  3328.407291    2.941176
# 253  2884.846830    5.735714
# 297  2700.245722    2.307692
# 788  3039.683222  197.898694
#
# [16 rows x 148 columns]

# %%
df['is_outlier_3σ'] = (df[source_cc50_variable] < lower_bound) | (df[source_cc50_variable] > upper_bound)

plt.figure(figsize=(10, 4))
plt.scatter(df.index, df[source_cc50_variable], c=~df['is_outlier_3σ'], cmap='coolwarm', label='Значения')
plt.axhline(y=lower_bound, color='r', linestyle='--', label='Нижняя граница (3σ)')
plt.axhline(y=upper_bound, color='r', linestyle='--', label='Верхняя граница (3σ)')
plt.legend()
plt.title('Обнаружение выбросов по правилу 3 сигм')
plt.show()

# %%
Q1 = df[source_cc50_variable].quantile(0.25)
Q3 = df[source_cc50_variable].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df["is_outlier_IQR"] = (df[source_cc50_variable] < lower_bound) | (df[source_cc50_variable] > upper_bound)
df[(df[source_cc50_variable] < lower_bound) | (df[source_cc50_variable] > upper_bound)]
# Out:
#      MaxAbsEStateIndex  MinAbsEStateIndex  MinEStateIndex       qed       SPS  \
# 28            0.162671          -0.598151        0.036863 -0.765315 -1.485425
# 29            0.167835          -0.492682       -0.336254 -0.374021 -1.320181
# 30            0.189542          -0.534596        0.041379 -0.600427 -1.479133
# 47           -1.758664           1.295320        0.865404 -1.586508  0.639545
# 49           -0.635122           0.032249        0.729359  0.664412  1.022232
# 50           -0.635122           0.032249        0.729359  0.664412  1.022232
# 52           -1.826221           1.260922        0.861699  0.649104  0.751162
# 80           -0.621559           0.484260        0.778045  0.676892  1.203891
# 81           -1.804546           1.252536        0.860796  0.426238  0.681620
# 82            0.279511          -1.022494        0.606901 -0.271209  1.382454
# 83            0.279511          -1.022494        0.606901 -0.271209  1.382454
# 84            0.207366          -0.912915        0.627556 -0.271209  1.382454
# 94            0.207366          -0.912915        0.627556 -0.271209  1.382454
# 95            0.279511          -1.022494        0.606901 -0.271209  1.382454
#
# 183         -0.169643  -0.085436   234.211171  4538.976189   19.379845
# 184         -0.169643  -0.085436  1131.658479  3328.407291    2.941176
# 253         -0.169643  -0.085436   502.962087  2884.846830    5.735714
# 297         -0.169643  -0.085436  1170.106480  2700.245722    2.307692
# 785         -0.169643  -0.085436    43.999197  2130.007494   48.410144
# 786         -0.169643  -0.085436    29.998894  2130.007494   71.002867
# 788         -0.169643  -0.085436    15.359794  3039.683222  197.898694
# 790         -0.169643  -0.085436    34.998710  2130.007494   60.859600
# 794         -0.169643  -0.085436   122.100332  2151.607844   17.621638
# 838         -0.169643  -0.085436    42.898638  2161.357833   50.382902
# 931         -0.169643  -0.085436   155.794987  2142.842325   13.754244
#
#      is_outlier_3σ  is_outlier_IQR
# 28           False            True
# 29            True            True
# 30            True            True
# 47           False            True
# 49            True            True
# 50           False            True
# 52           False            True
# 80            True            True
# 81           False            True
# 82            True            True
# 83            True            True
# 84            True            True
# 94            True            True
# 95            True            True
# 96           False            True
# 104          False            True
# 106          False            True
# 107          False            True
# 110           True            True
# 119          False            True
# 120          False            True
# 150          False            True
# 155          False            True
# 182           True            True
# 183           True            True
# 184           True            True
# 253           True            True
# 297           True            True
# 785          False            True
# 786          False            True
# 788           True            True
# 790          False            True
# 794          False            True
# 838          False            True
# 931          False            True
#
# [35 rows x 150 columns]

# %%
plt.figure(figsize=(10, 4))
plt.scatter(df.index, df[source_cc50_variable], c=~df['is_outlier_IQR'], cmap='coolwarm', label='Значения')
plt.axhline(y=lower_bound, color='r', linestyle='--', label='Нижняя граница (IQR)')
plt.axhline(y=upper_bound, color='r', linestyle='--', label='Верхняя граница (IQR)')
plt.legend()
plt.title('Обнаружение выбросов по правилу IQR')
plt.show()

# %%
df["log_10_CC50, mM"] = np.log10(df[source_cc50_variable])
target_old = source_cc50_variable
target = "log_10_CC50, mM"

# %%
mean = df[target].mean()
std = df[target].std()
lower_bound = mean - 3 * std
upper_bound = mean + 3 * std

outliers = df[(df[target] < lower_bound) | (df[target] > upper_bound)]

print("Выбросы по правилу 3 сигм:")
outliers
# Out:
# Выбросы по правилу 3 сигм:
#      MaxAbsEStateIndex  MinAbsEStateIndex  MinEStateIndex       qed       SPS  \
# 494           0.646747          -0.704660       -2.276510 -1.092152 -1.374389
# 650           0.713953          -0.766662        0.480211 -0.564401 -1.050408
# 735          -1.390456           0.713640        0.802752 -0.076737  2.451767
# 736          -1.390456           0.713640        0.802752 -0.076737  2.451767
# 762           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 763           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 764           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 765           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 766           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 767           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 768           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 769           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 779          -0.031877           0.236353       -0.197404 -0.636303  0.274890
# 780          -0.031877           0.236353       -0.197404 -0.636303  0.274890
# 781          -0.031877           0.236353       -0.197404 -0.636303  0.274890
# 819           0.627932          -0.850444       -0.032100 -2.082045 -0.510519
#
#         MolWt  MaxPartialCharge  MinPartialCharge  FpDensityMorgan1  \
# 494 -0.050563          1.543243          1.024606          0.670735
# 650  0.351183          0.156981          0.628572         -0.873178
# 735 -1.573665         -1.733732          1.106576         -1.339904
# 736 -1.573665         -1.733732          1.106576         -1.339904
# 762 -0.308884          0.749582         -0.711856          0.915935
# 763 -0.308884          0.749582         -0.711856          0.915935
# 764 -0.308884          0.749582         -0.711856          0.915935
# 765 -0.308884          0.749582         -0.711856          0.915935
# 766 -0.308884          0.749582         -0.711856          0.915935
# 767 -0.308884          0.749582         -0.711856          0.915935
# 768 -0.308884          0.749582         -0.711856          0.915935
# 769 -0.308884          0.749582         -0.711856          0.915935
# 779 -0.844150          0.393757          0.200854          1.601533
# 780 -0.844150          0.393757          0.200854          1.601533
# 781 -0.844150          0.393757          0.200854          1.601533
# 819  1.483087          0.727859         -0.915939         -0.163783
#
#      BCUT2D_MWHI  ...  fr_thiazole  fr_thiophene  fr_unbrch_alkane   fr_urea  \
# 494     0.593205  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 650     0.596027  ...    -0.238522       3.63399         -0.169643 -0.085436
# 735    -0.583817  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 736    -0.583817  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 762    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 763    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 764    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 765    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 766    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 767    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 768    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 769    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 779    -0.463048  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 780    -0.463048  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 781    -0.463048  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 819    -0.464432  ...    -0.238522      -0.27518         -0.169643 -0.085436
#
#       IC50, mM  CC50, mM          SI  is_outlier_3σ  is_outlier_IQR  \
# 494   0.275104  0.810833    2.947368          False           False
# 650   0.471609  1.664502    3.529412          False           False
# 735  60.996734  0.700808    0.011489          False           False
# 736  11.001362  0.700808    0.063702          False           False
# 762   0.108830  0.800223    7.352941          False           False
# 763   2.999235  0.800223    0.266809          False           False
# 764  29.000074  0.800223    0.027594          False           False
# 765   1.501218  0.800223    0.533049          False           False
# 766  16.001255  0.700995    0.043809          False           False
# 767  21.001047  0.700995    0.033379          False           False
# 768   0.150442  0.998678    6.638298          False           False
# 769   0.009603  0.998678  104.000000          False           False
# 779   9.999631  1.101516    0.110156          False           False
# 780   8.701563  1.101516    0.126588          False           False
# 781   8.201991  1.101516    0.134299          False           False
# 819   0.179381  0.880264    4.907216          False           False
#
#      log_10_CC50, mM
# 494        -0.091069
# 650         0.221284
# 735        -0.154401
# 736        -0.154401
# 762        -0.096789
# 763        -0.096789
# 764        -0.096789
# 765        -0.096789
# 766        -0.154285
# 767        -0.154285
# 768        -0.000575
# 769        -0.000575
# 779         0.041991
# 780         0.041991
# 781         0.041991
# 819        -0.055387
#
# [16 rows x 151 columns]

# %%
df['is_outlier_3σ'] = (df[target] < lower_bound) | (df[target] > upper_bound)

plt.figure(figsize=(10, 4))
plt.scatter(df.index, df[target], c=~df['is_outlier_3σ'], cmap='coolwarm', label='Значения')
plt.axhline(y=lower_bound, color='r', linestyle='--', label='Нижняя граница (3σ)')
plt.axhline(y=upper_bound, color='r', linestyle='--', label='Верхняя граница (3σ)')
plt.legend()
plt.title('Обнаружение выбросов по правилу 3 сигм')
plt.show()

# %%
Q1 = df[target].quantile(0.25)
Q3 = df[target].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df["is_outlier_IQR"] = (df[target] < lower_bound) | (df[target] > upper_bound)
df[(df[target] < lower_bound) | (df[target] > upper_bound)]
# Out:
#      MaxAbsEStateIndex  MinAbsEStateIndex  MinEStateIndex       qed       SPS  \
# 494           0.646747          -0.704660       -2.276510 -1.092152 -1.374389
# 650           0.713953          -0.766662        0.480211 -0.564401 -1.050408
# 735          -1.390456           0.713640        0.802752 -0.076737  2.451767
# 736          -1.390456           0.713640        0.802752 -0.076737  2.451767
# 762           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 763           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 764           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 765           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 766           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 767           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 768           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 769           0.323229          -0.700587        0.343971  0.529446 -0.366018
# 779          -0.031877           0.236353       -0.197404 -0.636303  0.274890
# 780          -0.031877           0.236353       -0.197404 -0.636303  0.274890
# 781          -0.031877           0.236353       -0.197404 -0.636303  0.274890
# 819           0.627932          -0.850444       -0.032100 -2.082045 -0.510519
# 861           0.613042          -0.950743       -2.237940  0.902636 -0.133872
# 918           0.842606          -0.055661        0.167586 -0.746398 -0.506336
# 920           0.439408          -0.175381        0.178249  0.332630 -0.625623
# 946           0.640008          -0.789827        0.339458 -1.466329  1.712324
# 948           0.678585          -0.836849        0.257717 -1.593174  1.549044
#
#         MolWt  MaxPartialCharge  MinPartialCharge  FpDensityMorgan1  \
# 494 -0.050563          1.543243          1.024606          0.670735
# 650  0.351183          0.156981          0.628572         -0.873178
# 735 -1.573665         -1.733732          1.106576         -1.339904
# 736 -1.573665         -1.733732          1.106576         -1.339904
# 762 -0.308884          0.749582         -0.711856          0.915935
# 763 -0.308884          0.749582         -0.711856          0.915935
# 764 -0.308884          0.749582         -0.711856          0.915935
# 765 -0.308884          0.749582         -0.711856          0.915935
# 766 -0.308884          0.749582         -0.711856          0.915935
# 767 -0.308884          0.749582         -0.711856          0.915935
# 768 -0.308884          0.749582         -0.711856          0.915935
# 769 -0.308884          0.749582         -0.711856          0.915935
# 779 -0.844150          0.393757          0.200854          1.601533
# 780 -0.844150          0.393757          0.200854          1.601533
# 781 -0.844150          0.393757          0.200854          1.601533
# 819  1.483087          0.727859         -0.915939         -0.163783
# 861 -0.015254          1.408114          0.207196          0.490922
# 918  1.540936          0.422494          1.423257         -0.914460
# 920  0.550478          0.393163          1.643134         -0.587957
# 946  0.720932          0.577248         -0.790557          0.187487
# 948  1.050844          0.577248         -0.790557          0.002858
#
#      BCUT2D_MWHI  ...  fr_thiazole  fr_thiophene  fr_unbrch_alkane   fr_urea  \
# 494     0.593205  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 650     0.596027  ...    -0.238522       3.63399         -0.169643 -0.085436
# 735    -0.583817  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 736    -0.583817  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 762    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 763    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 764    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 765    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 766    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 767    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 768    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 769    -0.465143  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 779    -0.463048  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 780    -0.463048  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 781    -0.463048  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 819    -0.464432  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 861     0.824730  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 918     0.824730  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 920     0.824730  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 946    -0.465687  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 948    -0.451172  ...    -0.238522      -0.27518         -0.169643 -0.085436
#
#       IC50, mM  CC50, mM          SI  is_outlier_3σ  is_outlier_IQR  \
# 494   0.275104  0.810833    2.947368           True            True
# 650   0.471609  1.664502    3.529412           True            True
# 735  60.996734  0.700808    0.011489           True            True
# 736  11.001362  0.700808    0.063702           True            True
# 762   0.108830  0.800223    7.352941           True            True
# 763   2.999235  0.800223    0.266809           True            True
# 764  29.000074  0.800223    0.027594           True            True
# 765   1.501218  0.800223    0.533049           True            True
# 766  16.001255  0.700995    0.043809           True            True
# 767  21.001047  0.700995    0.033379           True            True
# 768   0.150442  0.998678    6.638298           True            True
# 769   0.009603  0.998678  104.000000           True            True
# 779   9.999631  1.101516    0.110156           True            True
# 780   8.701563  1.101516    0.126588           True            True
# 781   8.201991  1.101516    0.134299           True            True
# 819   0.179381  0.880264    4.907216           True            True
# 861   0.017151  2.798526  163.166667          False            True
# 918   4.010129  2.369954    0.590992          False            True
# 920   4.271063  3.078863    0.720866          False            True
# 946   3.200851  3.500649    1.093662          False            True
# 948   2.899088  2.899088    1.000000          False            True
#
#      log_10_CC50, mM
# 494        -0.091069
# 650         0.221284
# 735        -0.154401
# 736        -0.154401
# 762        -0.096789
# 763        -0.096789
# 764        -0.096789
# 765        -0.096789
# 766        -0.154285
# 767        -0.154285
# 768        -0.000575
# 769        -0.000575
# 779         0.041991
# 780         0.041991
# 781         0.041991
# 819        -0.055387
# 861         0.446929
# 918         0.374740
# 920         0.488390
# 946         0.544149
# 948         0.462261
#
# [21 rows x 151 columns]

# %%
plt.figure(figsize=(10, 4))
plt.scatter(df.index, df[target], c=~df['is_outlier_IQR'], cmap='coolwarm', label='Значения')
plt.axhline(y=lower_bound, color='r', linestyle='--', label='Нижняя граница (IQR)')
plt.axhline(y=upper_bound, color='r', linestyle='--', label='Верхняя граница (IQR)')
plt.legend()
plt.title('Обнаружение выбросов по правилу 3 сигм')
plt.show()

# %% [markdown]
# Как видно, распределение близко к нормальному, поэтому отбросим выбросы по правлу 3-х сигм

# %%
df
# Out:
#      MaxAbsEStateIndex  MinAbsEStateIndex  MinEStateIndex       qed       SPS  \
# 0            -1.763647           1.227715        0.858123 -0.755891  1.073323
# 1            -2.108224           2.095440        0.951585 -0.544168  1.254983
# 2            -2.514136           2.150839        0.957552 -1.490120  1.014426
# 3            -1.762654           1.247702        0.860276 -0.941357  0.988562
# 4            -1.746485           0.536885        0.783714 -0.701088  0.563542
# ..                 ...                ...             ...       ...       ...
# 961           0.621634          -0.779389        0.307862 -0.918328  1.566453
# 962           0.834722          -0.884119        0.165598 -0.980878  1.201620
# 963           0.943127          -0.906571        0.196551 -1.377478  0.997433
# 964           0.893994          -0.196583       -0.286468 -0.923926  0.761096
# 965           0.757305          -1.049237        0.325811 -0.590671  1.522527
#
#         MolWt  MaxPartialCharge  MinPartialCharge  FpDensityMorgan1  \
# 0    0.258081         -1.556297          1.522921         -2.064995
# 1    0.289724         -1.759553          1.260180         -2.212699
# 2    0.745889         -1.118121          1.099403         -2.397328
# 3    0.368166         -1.556297          1.522921         -2.156673
# 4    0.902106         -1.367945          2.002451         -2.242239
# ..        ...               ...               ...               ...
# 961  0.492661          0.628761         -0.790557         -0.036530
# 962  1.050498          0.704502         -0.776102         -0.233468
# 963  1.522336          0.707042         -0.775993          0.065049
# 964  1.340989          0.586631         -0.792770         -1.593940
# 965  0.587270          0.577248         -0.790557         -0.321138
#
#      BCUT2D_MWHI  ...  fr_thiazole  fr_thiophene  fr_unbrch_alkane   fr_urea  \
# 0      -0.581532  ...    -0.238522      -0.27518          2.264143 -0.085436
# 1      -0.571135  ...    -0.238522      -0.27518          2.264143 -0.085436
# 2      -0.545366  ...    -0.238522      -0.27518          2.264143 -0.085436
# 3      -0.581603  ...    -0.238522      -0.27518          3.075405 -0.085436
# 4      -0.580930  ...    -0.238522      -0.27518         -0.169643 -0.085436
# ..           ...  ...          ...           ...               ...       ...
# 961    -0.461498  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 962    -0.461496  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 963     0.598260  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 964    -0.464683  ...    -0.238522      -0.27518         -0.169643 -0.085436
# 965    -0.465692  ...    -0.238522      -0.27518         -0.169643 -0.085436
#
#        IC50, mM    CC50, mM         SI  is_outlier_3σ  is_outlier_IQR  \
# 0      6.239374  175.482382  28.125000          False           False
# 1      0.771831    5.402819   7.000000          False           False
# 2    223.808778  161.142320   0.720000          False           False
# 3      1.705624  107.855654  63.235294          False           False
# 4    107.131532  139.270991   1.300000          False           False
# ..          ...         ...        ...            ...             ...
# 961   31.000104   34.999650   1.129017          False           False
# 962   31.999934   33.999415   1.062484          False           False
# 963   30.999883   33.999458   1.096761          False           False
# 964   31.998959   32.999644   1.031272          False           False
# 965   99.999531   99.999531   1.000000          False           False
#
#      log_10_CC50, mM
# 0           2.244234
# 1           0.732620
# 2           2.207210
# 3           2.032843
# 4           2.143861
# ..               ...
# 961         1.544064
# 962         1.531471
# 963         1.531472
# 964         1.518509
# 965         1.999998
#
# [966 rows x 151 columns]

# %%
# data_cleaned_IQR = df[~df['is_outlier_IQR']].drop(columns=['is_outlier_IQR', 'is_outlier_3σ'])
data_cleaned_IQR = df[~df['is_outlier_3σ']].drop(columns=['is_outlier_IQR', 'is_outlier_3σ
#
#      fr_unbrch_alkane   fr_urea
# 0            2.264143 -0.085436
# 1            2.264143 -0.085436
# 2            2.264143 -0.085436
# 3            3.075405 -0.085436
# 4           -0.169643 -0.085436
# ..                ...       ...
# 961         -0.169643 -0.085436
# 962         -0.169643 -0.085436
# 963         -0.169643 -0.085436
# 964         -0.169643 -0.085436
# 965         -0.169643 -0.085436
#
# [950 rows x 145 columns]

# %%
y_ic50
# Out:
# 0      2.244234
# 1      0.732620
# 2      2.207210
# 3      2.032843
# 4      2.143861
#          ...
# 961    1.544064
# 962    1.531471
# 963    1.531472
# 964    1.518509
# 965    1.999998
# Name: log_10_CC50, mM, Length: 950, dtype: float64

# %%
X_train, X_test, y_train_ic50, y_test_ic50 = train_test_split(
    X, y_ic50, test_size=0.2, random_state=42
)

# %% [markdown]
# print(f"Размер обучающей выборки: {len(X_train)}")
# print(f"Размер тестовой выборки: {len(X_test)}")

# %%
# Метрики
metrics = {
    'R2': r2_score,
    'RMSE': lambda y_true, y_pred: np.sqrt(mean_squared_error(y_true, y_pred)),
    'MAE': mean_absolute_error
}

# Модели и их гиперпараметры
MODELS = {
    'ridge': {
        'model': Ridge(random_state=112),
        'params': {
            'alpha': [0.01, 0.1, 1, 10, 100],
            'solver': ['auto', 'svd', 'cholesky']
        }
    },
    'rf': {
        'model': RandomForestRegressor(random_state=121),
        'params': {
            'n_estimators': [100, 200],
            'max_depth': [None, 10, 20],
            'min_samples_split': [2, 5]
        }
    },
    'xgb': {
        'model': XGBRegressor(random_state=111),
        'params': {
            'n_estimators': [100, 200],
            'max_depth': [3, 6],
            'learning_rate': [0.01, 0.1]
        }
    }
}

results = []

# Сразу ищем лучшую модель и лучшие результаты с подбором гипперпараметров
for name, config in MODELS.items():
    print(f"\nGridSearchCV для модели: {name}")

    grid = GridSearchCV(
        estimator=config['model'],
        param_grid=config['params'],
        cv=5,
        scoring='r2',
        n_jobs=-1,
        verbose=1
    )
    grid.fit(X_train, y_train_ic50)

    best_model = grid.best_estimator_

    y_pred = best_model.predict(X_test)

    # Метрики
    model_metrics = {}
    for metric_name, metric_func in metrics.items():
        model_metrics[metric_name] = metric_func(y_test_ic50, y_pred)

    results.append({
        'model_name': name,
        'model': best_model,  # Сохраняем саму модель
        'best_params': grid.best_params_,
        'cv_mean_r2': grid.best_score_,
        **model_metrics
    })

# Вывод результатов
results_df = pd.DataFrame(results)
results_df
# Out:
# GridSearchCV для модели: ridge
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
#
# GridSearchCV для модели: rf
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
#
# GridSearchCV для модели: xgb
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
#   model_name                                              model  \
# 0      ridge   Ridge(alpha=100, random_state=112, solver='svd')
# 1         rf  (DecisionTreeRegressor(max_depth=20, max_featu...
# 2        xgb  XGBRegressor(base_score=None, booster=None, ca...
#
#                                          best_params  cv_mean_r2        R2  \
# 0                    {'alpha': 100, 'solver': 'svd'}    0.388976  0.304938
# 1  {'max_depth': 20, 'min_samples_split': 5, 'n_e...    0.467701  0.418399
# 2  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...    0.443688  0.337910
#
#        RMSE       MAE
# 0  0.518750  0.404682
# 1  0.474525  0.351757
# 2  0.506296  0.371576

# %% [markdown]
# Лучшей моделью является RandomForestRegressor (rf), потому что:
#
# 1. У неё лучшее качество на тесте по R²: 0.418
# 2. Также наименьшие ошибки RMSE и MAE.
# 3. Хотя xgb и rf близки по cv_mean_r2, rf лучше обобщает на тесте
